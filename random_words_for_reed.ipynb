# %%
filename = '/content/gdrive/My Drive/google colab/10k_random.txt'

# %%
import re

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
with open(filename) as f:
  exp = "^m.+m$"
  content = f.readlines()
  for line in content:
    line = line.strip()
    if re.search(exp, line):
      print(line)
# Out:
# moderatism
# muscariform
# monoammonium
# millstream
# methodism
# megasporangium
# misaffirm
# megrim
# monophyleticism
# meconidium
# moralism
# mescalism
# mercantilism
# mesosternum
# mnemonism
# mimicism
# myocardium
